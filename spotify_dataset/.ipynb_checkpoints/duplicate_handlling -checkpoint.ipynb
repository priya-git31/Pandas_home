# %%
import pandas as pd
import numpy as np
import os

df = pd.read_csv('Top 100 most Streamed - Sheet1.csv')
df.head(2)
# Out:
#               title        artist                  top genre  year  \
# 0   Blinding Lights    The Weeknd  canadian contemporary r&b  2020
# 1  Watermelon Sugar  Harry Styles                        pop  2019
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
#
#    length  acousticness  speechiness  popularity
# 0     200             0            6          91
# 1     174            12            5          88

# %% [markdown]
# ### 1. duplicated()
#
# Returns a boolean Series → True if a row is a duplicate, False otherwise.
#
# By default, it checks all columns, but you can specify a subset.
#
# First occurrence of a duplicate is False, later ones are True.

# %%
df.duplicated()
 # check duplicate rows
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df['artist'].duplicated()
  # check duplicates only in 'artist'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96     True
# 97    False
# 98     True
# 99    False
# Name: artist, Length: 100, dtype: bool

# %%
df.duplicated(subset=['artist','title
 # check duplicates based on artist+title
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %% [markdown]
# ### 2. drop_duplicates()
#
# Removes duplicate rows.
#
# Keeps the first occurrence by default, but you can keep last or remove all.

# %%
df.drop_duplicates()
 # remove duplicate rows
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
# remove duplicate artists (keep first)
df.drop_duplicates(subset=['artist'])
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 91                              Lean On    Major Lazer
# 93                        Lose Yourself         Eminem
# 94         Without Me (with Juice WRLD)         Halsey
# 97                             Emotions     Mark Mendy
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
df.drop_duplicates(subset=['artist'],keep='last')
# keep last occurrence
# Out:
#                                   title         artist         top genre  \
# 1                      Watermelon Sugar   Harry Styles               pop
# 2                Mood (feat. iann dior)       24kGoldn          cali rap
# 3                     Someone You Loved  Lewis Capaldi               pop
# 12                 Say You Won't Let Go   James Arthur               pop
# 13                         Lucid Dreams     Juice WRLD       chicago rap
# ..                                  ...            ...               ...
# 95                            One Dance          Drake  canadian hip hop
# 96                                Sugar       Maroon 5               pop
# 97                             Emotions     Mark Mendy         pop dance
# 98                           Cold Water    Major Lazer         dance pop
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner         dance pop
#
#     year  beats.per.minute  energy  danceability  loudness.dB  liveness  \
# ...

# %%
df.drop_duplicates(subset=['artist'],keep=False)
 # remove all duplicates
# Out:
#                                                 title  \
# 1                                    Watermelon Sugar
# 2                              Mood (feat. iann dior)
# 3                                   Someone You Loved
# 12                               Say You Won't Let Go
# 13                                       Lucid Dreams
# 14                                          All of Me
# 18                                         Wake Me Up
# 19                       ROCKSTAR (feat. Roddy Ricch)
# 25                              Roses - Imanbek Remix
# 26                                            The Box
# 33                                            Shallow
# 35                                      XO Tour Llif3
# 36                                  Take Me To Church
# 37                                            Happier
# 39                                     Counting Stars
# 40                   Can't Hold Us - feat. Ray Dalton
# ...

# %% [markdown]
# ### Practice Questions

# %%
# Find how many duplicate songs (same title) exist.

df['title'].duplicated().sum()
# Out:
# 0

# %%
# Remove duplicates based on title and artist.

df.drop_duplicates(subset=['artist','title'],keep=False);

# %%
# Keep only the last occurrence of each duplicate artist.

df.drop_duplicates(subset=['artist'],keep='last')
# Out:
#                                   title         artist         top genre  \
# 1                      Watermelon Sugar   Harry Styles               pop
# 2                Mood (feat. iann dior)       24kGoldn          cali rap
# 3                     Someone You Loved  Lewis Capaldi               pop
# 12                 Say You Won't Let Go   James Arthur               pop
# 13                         Lucid Dreams     Juice WRLD       chicago rap
# ..                                  ...            ...               ...
# 95                            One Dance          Drake  canadian hip hop
# 96                                Sugar       Maroon 5               pop
# 97                             Emotions     Mark Mendy         pop dance
# 98                           Cold Water    Major Lazer         dance pop
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner         dance pop
#
#     year  beats.per.minute  energy  danceability  loudness.dB  liveness  \
# ...

# %%
# Drop all duplicate year values, keeping just the first.

df.drop_duplicates(subset=['year'],keep='first')
# Out:
#                                   title                   artist  \
# 0                       Blinding Lights               The Weeknd
# 1                      Watermelon Sugar             Harry Styles
# 2                Mood (feat. iann dior)                 24kGoldn
# 4                               Perfect               Ed Sheeran
# 6                  lovely (with Khalid)            Billie Eilish
# 10                               Closer         The Chainsmokers
# 14                            All of Me              John Legend
# 21                           Photograph               Ed Sheeran
# 24                         Stressed Out        Twenty One Pilots
# 40     Can't Hold Us - feat. Ray Dalton  Macklemore & Ryan Lewis
# 44  Bohemian Rhapsody - Remastered 2011                    Queen
# 53                       Mr. Brightside              The Killers
# 68                            I'm Yours               Jason Mraz
# ...

# %%
# Count how many duplicates exist across the entire DataFrame.

df.duplicated().sum()
# Out:
# 0
