# %%
import pandas as pd
import numpy as np
import os

df = pd.read_csv('Top 100 most Streamed - Sheet1.csv')
df.head(2)
# Out:
#               title        artist                  top genre  year  \
# 0   Blinding Lights    The Weeknd  canadian contemporary r&b  2020
# 1  Watermelon Sugar  Harry Styles                        pop  2019
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
#
#    length  acousticness  speechiness  popularity
# 0     200             0            6          91
# 1     174            12            5          88

# %% [markdown]
# ### drop() → Remove Rows or Columns
#
# Removes rows (by index) or columns (by name).
#
# Does not change the DataFrame unless you use inplace=True.

# %%
# Drop rows by index
# removes first 2 rows
df.drop([0,1])
# Out:
#                                   title           artist         top genre  \
# 2                Mood (feat. iann dior)         24kGoldn          cali rap
# 3                     Someone You Loved    Lewis Capaldi               pop
# 4                               Perfect       Ed Sheeran               pop
# 5                              Believer  Imagine Dragons       modern rock
# 6                  lovely (with Khalid)    Billie Eilish        electropop
# ..                                  ...              ...               ...
# 95                            One Dance            Drake  canadian hip hop
# 96                                Sugar         Maroon 5               pop
# 97                             Emotions       Mark Mendy         pop dance
# 98                           Cold Water      Major Lazer         dance pop
# 99  I Took A Pill In Ibiza - Seeb Remix      Mike Posner         dance pop
#
# ...

# %%
df.drop(['artist','year'], axis=1)
# Out:
#                                   title                  top genre  \
# 0                       Blinding Lights  canadian contemporary r&b
# 1                      Watermelon Sugar                        pop
# 2                Mood (feat. iann dior)                   cali rap
# 3                     Someone You Loved                        pop
# 4                               Perfect                        pop
# ..                                  ...                        ...
# 95                            One Dance           canadian hip hop
# 96                                Sugar                        pop
# 97                             Emotions                  pop dance
# 98                           Cold Water                  dance pop
# 99  I Took A Pill In Ibiza - Seeb Remix                  dance pop
#
#     beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0                171      73            51           -6         9       33
# ...

# %%
df.drop(5)
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %% [markdown]
# ### isin() → Check Membership in a List
#
# Returns True/False if values exist in a given list.
#
# Used inside loc for filtering.

# %%
df['artist'].isin(['Drake'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96    False
# 97    False
# 98    False
# 99    False
# Name: artist, Length: 100, dtype: bool

# %%
df.loc[df['artist'].isin(['Drake','The Weeknd'])]
# Out:
#                  title      artist                  top genre  year  \
# 0      Blinding Lights  The Weeknd  canadian contemporary r&b  2020
# 27           The Hills  The Weeknd  canadian contemporary r&b  2015
# 30             Starboy  The Weeknd  canadian contemporary r&b  2016
# 42          God's Plan       Drake           canadian hip hop  2018
# 77  Can't Feel My Face  The Weeknd  canadian contemporary r&b  2015
# 95           One Dance       Drake           canadian hip hop  2016
#
#     beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0                171      73            51           -6         9       33
# 27               113      56            59           -7        14       14
# 30               186      59            68           -7        14       49
# 42                77      45            75           -9        55       36
# 77               108      77            71           -6        11       58
# ...

# %% [markdown]
# ### between() → Range Checking
#
# Checks whether values lie within a range (inclusive).

# %%
df['year'].between(2018,2019)
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98     True
# 99    False
# Name: year, Length: 100, dtype: bool

# %%
df.loc[df['year'].between(2019,2020)]
# Out:
#                                 title         artist  \
# 0                     Blinding Lights     The Weeknd
# 1                    Watermelon Sugar   Harry Styles
# 3                   Someone You Loved  Lewis Capaldi
# 7                             Circles    Post Malone
# 11                            bad guy  Billie Eilish
# 15                            7 rings  Ariana Grande
# 19       ROCKSTAR (feat. Roddy Ricch)         DaBaby
# 25              Roses - Imanbek Remix      SAINt JHN
# 26                            The Box    Roddy Ricch
# 38                      thank u, next  Ariana Grande
# 41                           Señorita   Shawn Mendes
# 43                    Don't Start Now       Dua Lipa
# 52              when the party's over  Billie Eilish
# 54                       Dance Monkey    Tones And I
# 57  I Don't Care (with Justin Bieber)     Ed Sheeran
# 67              Old Town Road - Remix      Lil Nas X
# 78                          Despacito     Luis Fonsi
# ...
