# %%
import pandas as pd
import numpy as np
import os

df = pd.read_csv('Top 100 most Streamed - Sheet1.csv')
df.head(2)
# Out:
#               title        artist                  top genre  year  \
# 0   Blinding Lights    The Weeknd  canadian contemporary r&b  2020
# 1  Watermelon Sugar  Harry Styles                        pop  2019
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
#
#    length  acousticness  speechiness  popularity
# 0     200             0            6          91
# 1     174            12            5          88

# %% [markdown]
# ### 19. rename() → Alter Axis Labels
#
# Used to rename columns or row indexes.

# %%
df.rename(columns={'artist':'singer','title':'song'},inplace=True)
df.head(1)
# Out:
#               song      singer                  top genre  year  \
# 0  Blinding Lights  The Weeknd  canadian contemporary r&b  2020
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
#
#    length  acousticness  speechiness  popularity
# 0     200             0            6          91

# %%
df.rename(index={0:'first_song',1:'second_song'})
# Out:
#                                             song         singer  \
# first_song                       Blinding Lights     The Weeknd
# second_song                     Watermelon Sugar   Harry Styles
# 2                         Mood (feat. iann dior)       24kGoldn
# 3                              Someone You Loved  Lewis Capaldi
# 4                                        Perfect     Ed Sheeran
# ...                                          ...            ...
# 95                                     One Dance          Drake
# 96                                         Sugar       Maroon 5
# 97                                      Emotions     Mark Mendy
# 98                                    Cold Water    Major Lazer
# 99           I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                              top genre  year  beats.per.minute  energy  \
# first_song   canadian contemporary r&b  2020               171      73
# ...

# %% [markdown]
# ###  clip() → Limit Values
#
# Clips values at specified lower and upper bounds.

# %%
   # all values <50 become 50, >90 become 90
df['popularity'].clip(lower=50,upper=90)
# Out:
# 0     90
# 1     88
# 2     88
# 3     86
# 4     86
#       ..
# 95    66
# 96    66
# 97    66
# 98    56
# 99    53
# Name: popularity, Length: 100, dtype: int64

# %%
# restrict values between 0–100
df['energy'].clip(0,100)
# Out:
# 0     73
# 1     82
# 2     72
# 3     41
# 4     45
#       ..
# 95    61
# 96    79
# 97    83
# 98    80
# 99    73
# Name: energy, Length: 100, dtype: int64
